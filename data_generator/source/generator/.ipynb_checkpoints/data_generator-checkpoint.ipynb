# %%
pip install treelib

# %%
from treelib import Node, Tree
import csv
from concurrent.futures import ThreadPoolExecutor
import random
import os
import json
import pprint

# %%
def set_fd(my_dict={}):    
    my_dict = {
        "level1": {
            "is_parent": True,
            "number_of_distinct_vals": 25,
            "total_vals": 0,
            "dups": 2,
            "number_of_dup_values": 20
            #,
            #"key_2": "test2"
        },
        "level2": {
            "is_parent": True,
            "number_of_distinct_vals": 3,
            "total_vals": 0,
            "dups": 0,
            "number_of_dup_values": 3
            #,
            #"key_2": "test2"
        },
        "level3": {
            "is_parent": False,
            "number_of_distinct_vals": 3,
            "total_vals": 0, #number of distinct values * number of dups of last level,
            "dups": 3,
            "number_of_dup_values": 3
            #,
            #"key_2": "test2"
        },
        "level4": {
            "is_parent": False,
            "number_of_distinct_vals": 2,
            "total_vals": 0,
            "dups": 4,
            "number_of_dup_values": 2
            #,
            #"key_2": "test2"
        },
        "level5": {
            "is_parent": False,
            "number_of_distinct_vals": 4,
            "total_vals": 0,
            "dups": 3,
            "number_of_dup_values": 4
            #,
            #"key_2": "test2"
        },
        "level6": {
            "is_parent": False,
            "number_of_distinct_vals": 5,
            "total_vals": 0,
            "dups": 2,
            "number_of_dup_values": 4
            #,
            #"key_2": "test2"
        },
        "level7": {
            "is_parent": True,
            "number_of_distinct_vals": 3,
            "total_vals": 0,
            "dups": 0,
            "number_of_dup_values": 3
            #,
            #"key_2": "test2"
        },
        "level8": {
            "is_parent": False,
            "number_of_distinct_vals": 2,
            "total_vals": 0,
            "dups": 0,
            "number_of_dup_values": 0
            #,
            #"key_2": "test2"
        }
    }
    return my_dict

# %%
def update_input(current_level=1,first_level=8,fd_dict={}):
    v_add_up=1
    v_distinct_values=2
    if fd_dict["level"+str(current_level)]["is_parent"]==False and fd_dict["level"+str(current_level)]["total_vals"]==0 and current_level+1<=first_level:
        v_add_up=v_add_up*fd_dict["level"+str(current_level)]["number_of_distinct_vals"]*update_input(current_level+1,fd_dict=fd_dict)
        fd_dict["level"+str(current_level)]["total_vals"]=v_add_up
        #if fd_dict["level"+str(current_level+1)]["is_parent"]==True:
        #    v_add_up=v_add_up*fd_dict["level"+str(current_level)]["dups"]
        #    fd_dict["level"+str(current_level)]["total_vals"]=v_add_up
        #else:
        #    fd_dict["level"+str(current_level)]["total_vals"]=v_add_up
    elif fd_dict["level"+str(current_level)]["is_parent"]==False and fd_dict["level"+str(current_level)]["total_vals"]==0 and current_level+1>first_level:
        fd_dict["level"+str(current_level)]["total_vals"]=v_distinct_values
    elif fd_dict["level"+str(current_level)]["is_parent"]==True:
        v_add_up=fd_dict["level"+str(current_level)]["number_of_distinct_vals"]
    return v_add_up

# %%
first_level=8
my_dict2={}
my_dict2=set_fd(my_dict2)
for i in range(1,first_level+1):
    update_input(i,first_level,my_dict2)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(my_dict2)
# Out:
# {   'level1': {   'dups': 2,
#                   'is_parent': True,
#                   'number_of_distinct_vals': 25,
#                   'number_of_dup_values': 20,
#                   'total_vals': 0},
#     'level2': {   'dups': 0,
#                   'is_parent': True,
#                   'number_of_distinct_vals': 3,
#                   'number_of_dup_values': 3,
#                   'total_vals': 0},
#     'level3': {   'dups': 3,
#                   'is_parent': False,
#                   'number_of_distinct_vals': 3,
#                   'number_of_dup_values': 3,
#                   'total_vals': 360},
#     'level4': {   'dups': 4,
#                   'is_parent': False,
#                   'number_of_distinct_vals': 2,
#                   'number_of_dup_values': 2,
#                   'total_vals': 120},
#     'level5': {   'dups': 3,
#                   'is_parent': False,
#                   'number_of_distinct_vals': 4,
#                   'number_of_dup_values': 4,
#                   'total_vals': 60},
#     'level6': {   'dups': 2,
#                   'is_parent': False,
#                   'number_of_distinct_vals': 5,
#                   'number_of_dup_values': 4,
#                   'total_vals': 15},
#     'level7': {   'dups': 0,
#                   'is_parent': True,
#                   'number_of_distinct_vals': 3,
#                   'number_of_dup_values': 3,
#                   'total_vals': 0},
#     'level8': {   'dups': 0,
#                   'is_parent': False,
#                   'number_of_distinct_vals': 2,
#                   'number_of_dup_values': 0,
#                   'total_vals': 2}}

# %%
def set_col_headers(new_file,first_level,letter):
    with open(new_file, 'a+',newline="") as f_out:
        for i in range(1,first_level+1):
            if first_level!=i:
                f_out.write(chr(letter+first_level-i)+',')
            else:
                f_out.write(chr(letter+first_level-i)+'\n')

# %%
my_dict2={}

# %%
def generate_data(level=0,first_level=8,tree=Tree(),parent="",parent_index=0,letter=65,num_of_dups=3,out_text="",dup_sink_rate=1,start=1,end=3,FD_dict={},addup=0):
    try:
        global my_dict2
        if level!=0:
            num_of_dups=my_dict2["level"+str(level)]["dups"]
            is_parent=my_dict2["level"+str(level)]["is_parent"]  #it should be automatic (as input)
            if my_dict2["level"+str(level)]["dups"]!=0:
                dup_enabled=True
            else:
                dup_enabled=False #it should be automatic (as input)
        number_of_dup_values=5 #it should be clacualted (according to some formula based on the total number of records)
        #number_of_values=5 #it should be clacualted (according to some formula based on the total number of records)
        v_letter=65
        if level==first_level:
            if is_parent==False:
                num_of_distinct_vals=my_dict2["level"+str(level)]["number_of_distinct_vals"]
                for i in range(1,num_of_distinct_vals+1):
                #for i in range(1,3):
                    tree.create_node(chr(letter)+str(i), out_text+chr(letter)+str(i),parent)
                    new_file="tree.csv"
                    with open(new_file, 'a+',newline="") as f_out:
                        f_out.write(out_text+chr(letter)+str(i)+"\n")
            else:
                for i in range(start,end):
                    tree.create_node(chr(letter)+str(i),out_text+chr(letter)+str(i),parent)
                    new_file="tree.csv"
                    with open(new_file, 'a+',newline="") as f_out:
                        f_out.write(out_text+chr(letter)+str(i)+"\n") 
        else:
            if level!=0:
                if level==1:
                    number_of_values=my_dict2["level"+str(level)]["number_of_distinct_vals"] #it should be clacualted (according to some formula based on the total number of records)
                    for i in range(1,number_of_values+1):
                        next_num_of_distinct_vals=my_dict2["level"+str(level+1)]["number_of_distinct_vals"]
                        #start_point=(i-1)*next_num_of_distinct_vals+1
                        #end_point=(i-1)*next_num_of_distinct_vals+next_num_of_distinct_vals+1
                        if i>number_of_dup_values:
                            start_point=(number_of_dup_values)*next_num_of_distinct_vals+(i-number_of_dup_values)
                            end_point=(number_of_dup_values)*next_num_of_distinct_vals+(i-number_of_dup_values)+1
                            #end_point=(i-1)*num_of_dups+2
                        else:
                            start_point=(i-1)*next_num_of_distinct_vals+1
                            end_point=(i)*next_num_of_distinct_vals+1
                            #end_point=(i-1)*num_of_dups+num_of_dups+1
                        #if i>number_of_dup_values:
                        #    end_point=(i-1)*num_of_dups+2
                        #else:
                        #    end_point=(i-1)*num_of_dups+num_of_dups+1
                        out_text=out_text.replace(chr(letter)+str(i-1)+",","")
                        out_text=out_text+chr(letter)+str(i)+","
                        tree.create_node(chr(letter)+str(i),out_text,parent)
                        generate_data(level+1,first_level,tree,parent=out_text,parent_index=i,letter=v_letter+first_level-level-1,num_of_dups=int(num_of_dups*dup_sink_rate),out_text=out_text,start=start_point,end=end_point)
                else:
                    if is_parent==False:
                        #num_of_distinct_vals=num_of_dups
                        num_of_distinct_vals=my_dict2["level"+str(level)]["number_of_distinct_vals"]
                        next_num_of_distinct_vals=my_dict2["level"+str(level+1)]["number_of_distinct_vals"]
                        number_of_dup_values=my_dict2["level"+str(level+1)]["number_of_dup_values"]
                        for i in range(1,num_of_distinct_vals+1):
                            v_addup=addup+(parent_index-1)*my_dict2["level"+str(level)]["total_vals"]
                            if parent_index>1:
                                zarib=parent_index-1
                            else:
                                zarib=0
                            if i>number_of_dup_values:
                            #if dup_enabled==False:
                                start_point=v_addup+(number_of_dup_values)*next_num_of_distinct_vals+(i-number_of_dup_values)+zarib*(number_of_dup_values-num_of_distinct_vals)
                                end_point=v_addup+(number_of_dup_values)*next_num_of_distinct_vals+(i-number_of_dup_values)+1+zarib*(number_of_dup_values-num_of_distinct_vals)
                                #start_point=((i-1)*next_num_of_distinct_vals)+1
                                #end_point=((i-1)*next_num_of_distinct_vals)+2
                                #start_point=((i-1)*num_of_dups)+1
                                #end_point=((i-1)*num_of_dups)+2
                            else:
                                start_point=v_addup+(i-1)*next_num_of_distinct_vals+1+zarib*(number_of_dup_values-num_of_distinct_vals)
                                end_point=v_addup+i*next_num_of_distinct_vals+1+zarib*(number_of_dup_values-num_of_distinct_vals)
                                #start_point=v_addup+(i-1)*num_of_dups+1
                                #end_point=v_addup+i*num_of_dups+1
                            out_text=out_text.replace(chr(letter)+str(i-1)+",","")
                            out_text=out_text+chr(letter)+str(i)+","
                            tree.create_node(chr(letter)+str(i),out_text,parent)
                            generate_data(level+1,first_level,tree,parent=out_text,parent_index=i,letter=v_letter+first_level-level-1,num_of_dups=int(num_of_dups*dup_sink_rate),out_text=out_text,start=start_point,end=end_point,addup=v_addup)
                    else:
                        for i in range(start,end):
                            num_of_distinct_vals=my_dict2["level"+str(level)]["number_of_distinct_vals"]
                            next_num_of_distinct_vals=my_dict2["level"+str(level+1)]["number_of_distinct_vals"]
                            number_of_dup_values=my_dict2["level"+str(level+1)]["number_of_dup_values"]
                            if parent_index>1:
                                zarib=parent_index-1
                            else:
                                zarib=0
                            if i>number_of_dup_values:
                                start_point=(number_of_dup_values)*next_num_of_distinct_vals+(i-number_of_dup_values)+zarib*(number_of_dup_values-num_of_distinct_vals)
                                end_point=(number_of_dup_values)*next_num_of_distinct_vals+(i-number_of_dup_values)+1+zarib*(number_of_dup_values-num_of_distinct_vals)
                            else:
                                start_point=(i-1)*next_num_of_distinct_vals+1+zarib*(number_of_dup_values-num_of_distinct_vals)
                                end_point=i*next_num_of_distinct_vals+1+zarib*(number_of_dup_values-num_of_distinct_vals)
                            #if dup_enabled==False:
                            #    start_point=((i-1)*num_of_dups)+1
                            #    end_point=((i-1)*num_of_dups)+2
                            #else:
                            #    start_point=((i-1)*num_of_dups)+1
                            #    end_point=((i-1)*num_of_dups)+num_of_dups+1
                            out_text=out_text.replace(chr(letter)+str(i-1)+",","")
                            out_text=out_text+chr(letter)+str(i)+","
                            tree.create_node(chr(letter)+str(i),out_text,parent)
                            generate_data(level+1,first_level,tree,parent=out_text,parent_index=i,letter=v_letter+first_level-level-1,num_of_dups=int(num_of_dups*dup_sink_rate),out_text=out_text,start=start_point,end=end_point,addup=0)
            else:
                try:
                    os.remove("tree.csv")
                except FileNotFoundError:
                    pass
                new_file="tree.csv"
                set_col_headers(new_file,first_level,v_letter)
                my_dict2=set_fd(my_dict2)
                for i in range(1,first_level+1):
                    update_input(i,first_level,my_dict2)
                tree.create_node("root", "root")
                generate_data(level+1,first_level,tree,parent="root",letter=v_letter+first_level-level-1)
        if level==0:
            print(tree.show())
    except Exception as e:
        print(e)

# %%
generate_data()
# Out:
# root
# ├── H1
# │   ├── G1
# │   │   ├── F1
# │   │   │   ├── E1
# │   │   │   │   ├── D1
# │   │   │   │   │   ├── C1
# │   │   │   │   │   │   ├── B1
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B2
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B3
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C2
# │   │   │   │   │   │   ├── B4
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B5
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B6
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C3
# │   │   │   │   │   │   ├── B7
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B8
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B9
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C4
# │   │   │   │   │   │   └── B10
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   └── C5
# │   │   │   │   │       └── B11
# │   │   │   │   │           ├── A1
# │   │   │   │   │           └── A2
# │   │   │   │   ├── D2
# │   │   │   │   │   ├── C1
# │   │   │   │   │   │   ├── B14
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B15
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B16
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C2
# │   │   │   │   │   │   ├── B17
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B18
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B19
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C3
# │   │   │   │   │   │   ├── B20
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B21
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B22
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C4
# │   │   │   │   │   │   └── B23
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   └── C5
# │   │   │   │   │       └── B24
# │   │   │   │   │           ├── A1
# │   │   │   │   │           └── A2
# │   │   │   │   ├── D3
# │   │   │   │   │   ├── C1
# │   │   │   │   │   │   ├── B27
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B28
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B29
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C2
# │   │   │   │   │   │   ├── B30
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B31
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B32
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C3
# │   │   │   │   │   │   ├── B33
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B34
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B35
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C4
# │   │   │   │   │   │   └── B36
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   └── C5
# │   │   │   │   │       └── B37
# │   │   │   │   │           ├── A1
# │   │   │   │   │           └── A2
# │   │   │   │   └── D4
# │   │   │   │       ├── C1
# │   │   │   │       │   ├── B40
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   ├── B41
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   └── B42
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       ├── C2
# │   │   │   │       │   ├── B43
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   ├── B44
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   └── B45
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       ├── C3
# │   │   │   │       │   ├── B46
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   ├── B47
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   └── B48
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       ├── C4
# │   │   │   │       │   └── B49
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       └── C5
# │   │   │   │           └── B50
# │   │   │   │               ├── A1
# │   │   │   │               └── A2
# │   │   │   └── E2
# │   │   │       ├── D1
# │   │   │       │   ├── C1
# │   │   │       │   │   ├── B61
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B62
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B63
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C2
# │   │   │       │   │   ├── B64
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B65
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B66
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C3
# │   │   │       │   │   ├── B67
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B68
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B69
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C4
# │   │   │       │   │   └── B70
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   └── C5
# │   │   │       │       └── B71
# │   │   │       │           ├── A1
# │   │   │       │           └── A2
# │   │   │       ├── D2
# │   │   │       │   ├── C1
# │   │   │       │   │   ├── B74
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B75
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B76
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C2
# │   │   │       │   │   ├── B77
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B78
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B79
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C3
# │   │   │       │   │   ├── B80
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B81
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B82
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C4
# │   │   │       │   │   └── B83
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   └── C5
# │   │   │       │       └── B84
# │   │   │       │           ├── A1
# │   │   │       │           └── A2
# │   │   │       ├── D3
# │   │   │       │   ├── C1
# │   │   │       │   │   ├── B87
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B88
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B89
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C2
# │   │   │       │   │   ├── B90
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B91
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B92
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C3
# │   │   │       │   │   ├── B93
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B94
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B95
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C4
# │   │   │       │   │   └── B96
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   └── C5
# │   │   │       │       └── B97
# │   │   │       │           ├── A1
# │   │   │       │           └── A2
# │   │   │       └── D4
# │   │   │           ├── C1
# │   │   │           │   ├── B100
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   ├── B101
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   └── B102
# │   │   │           │       ├── A1
# │   │   │           │       └── A2
# │   │   │           ├── C2
# │   │   │           │   ├── B103
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   ├── B104
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   └── B105
# │   │   │           │       ├── A1
# │   │   │           │       └── A2
# │   │   │           ├── C3
# │   │   │           │   ├── B106
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   ├── B107
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   └── B108
# │   │   │           │       ├── A1
# │   │   │           │       └── A2
# │   │   │           ├── C4
# │   │   │           │   └── B109
# │   │   │           │       ├── A1
# │   │   │           │       └── A2
# │   │   │           └── C5
# │   │   │               └── B110
# │   │   │                   ├── A1
# │   │   │                   └── A2
# │   │   ├── F2
# │   │   │   ├── E1
# │   │   │   │   ├── D1
# │   │   │   │   │   ├── C1
# │   │   │   │   │   │   ├── B121
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B122
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B123
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C2
# │   │   │   │   │   │   ├── B124
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B125
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B126
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C3
# │   │   │   │   │   │   ├── B127
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B128
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B129
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C4
# │   │   │   │   │   │   └── B130
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   └── C5
# │   │   │   │   │       └── B131
# │   │   │   │   │           ├── A1
# │   │   │   │   │           └── A2
# │   │   │   │   ├── D2
# │   │   │   │   │   ├── C1
# │   │   │   │   │   │   ├── B134
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B135
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B136
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C2
# │   │   │   │   │   │   ├── B137
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B138
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B139
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C3
# │   │   │   │   │   │   ├── B140
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B141
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B142
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C4
# │   │   │   │   │   │   └── B143
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   └── C5
# │   │   │   │   │       └── B144
# │   │   │   │   │           ├── A1
# │   │   │   │   │           └── A2
# │   │   │   │   ├── D3
# │   │   │   │   │   ├── C1
# │   │   │   │   │   │   ├── B147
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B148
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B149
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C2
# │   │   │   │   │   │   ├── B150
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B151
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B152
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C3
# │   │   │   │   │   │   ├── B153
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B154
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B155
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C4
# │   │   │   │   │   │   └── B156
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   └── C5
# │   │   │   │   │       └── B157
# │   │   │   │   │           ├── A1
# │   │   │   │   │           └── A2
# │   │   │   │   └── D4
# │   │   │   │       ├── C1
# │   │   │   │       │   ├── B160
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   ├── B161
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   └── B162
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       ├── C2
# │   │   │   │       │   ├── B163
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   ├── B164
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   └── B165
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       ├── C3
# │   │   │   │       │   ├── B166
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   ├── B167
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   └── B168
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       ├── C4
# │   │   │   │       │   └── B169
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       └── C5
# │   │   │   │           └── B170
# │   │   │   │               ├── A1
# │   │   │   │               └── A2
# │   │   │   └── E2
# │   │   │       ├── D1
# │   │   │       │   ├── C1
# │   │   │       │   │   ├── B181
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B182
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B183
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C2
# │   │   │       │   │   ├── B184
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B185
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B186
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C3
# │   │   │       │   │   ├── B187
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B188
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B189
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C4
# │   │   │       │   │   └── B190
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   └── C5
# │   │   │       │       └── B191
# │   │   │       │           ├── A1
# │   │   │       │           └── A2
# │   │   │       ├── D2
# │   │   │       │   ├── C1
# │   │   │       │   │   ├── B194
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B195
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B196
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C2
# │   │   │       │   │   ├── B197
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B198
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B199
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C3
# │   │   │       │   │   ├── B200
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B201
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B202
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C4
# │   │   │       │   │   └── B203
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   └── C5
# │   │   │       │       └── B204
# │   │   │       │           ├── A1
# │   │   │       │           └── A2
# │   │   │       ├── D3
# │   │   │       │   ├── C1
# │   │   │       │   │   ├── B207
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B208
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B209
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C2
# │   │   │       │   │   ├── B210
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B211
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B212
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C3
# │   │   │       │   │   ├── B213
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B214
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B215
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C4
# │   │   │       │   │   └── B216
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   └── C5
# │   │   │       │       └── B217
# │   │   │       │           ├── A1
# │   │   │       │           └── A2
# │   │   │       └── D4
# │   │   │           ├── C1
# │   │   │           │   ├── B220
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   ├── B221
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   └── B222
# │   │   │           │       ├── A1
# │   │   │           │       └── A2
# │   │   │           ├── C2
# │   │   │           │   ├── B223
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   ├── B224
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   └── B225
# │   │   │           │       ├── A1
# │   │   │           │       └── A2
# │   │   │           ├── C3
# │   │   │           │   ├── B226
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   ├── B227
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   └── B228
# │   │   │           │       ├── A1
# │   │   │           │       └── A2
# │   │   │           ├── C4
# │   │   │           │   └── B229
# │   │   │           │       ├── A1
# │   │   │           │       └── A2
# │   │   │           └── C5
# │   │   │               └── B230
# │   │   │                   ├── A1
# │   │   │                   └── A2
# │   │   └── F3
# │   │       ├── E1
# │   │       │   ├── D1
# │   │       │   │   ├── C1
# │   │       │   │   │   ├── B241
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   ├── B242
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   └── B243
# │   │       │   │   │       ├── A1
# │   │       │   │   │       └── A2
# │   │       │   │   ├── C2
# │   │       │   │   │   ├── B244
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   ├── B245
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   └── B246
# │   │       │   │   │       ├── A1
# │   │       │   │   │       └── A2
# │   │       │   │   ├── C3
# │   │       │   │   │   ├── B247
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   ├── B248
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   └── B249
# │   │       │   │   │       ├── A1
# │   │       │   │   │       └── A2
# │   │       │   │   ├── C4
# │   │       │   │   │   └── B250
# │   │       │   │   │       ├── A1
# │   │       │   │   │       └── A2
# │   │       │   │   └── C5
# │   │       │   │       └── B251
# │   │       │   │           ├── A1
# │   │       │   │           └── A2
# │   │       │   ├── D2
# │   │       │   │   ├── C1
# │   │       │   │   │   ├── B254
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   ├── B255
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   └── B256
# │   │       │   │   │       ├── A1
# │   │       │   │   │       └── A2
# │   │       │   │   ├── C2
# │   │       │   │   │   ├── B257
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   ├── B258
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   └── B259
# │   │       │   │   │       ├── A1
# │   │       │   │   │       └── A2
# │   │       │   │   ├── C3
# │   │       │   │   │   ├── B260
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   ├── B261
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   └── B262
# │   │       │   │   │       ├── A1
# │   │       │   │   │       └── A2
# │   │       │   │   ├── C4
# │   │       │   │   │   └── B263
# │   │       │   │   │       ├── A1
# │   │       │   │   │       └── A2
# │   │       │   │   └── C5
# │   │       │   │       └── B264
# │   │       │   │           ├── A1
# │   │       │   │           └── A2
# │   │       │   ├── D3
# │   │       │   │   ├── C1
# │   │       │   │   │   ├── B267
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   ├── B268
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   └── B269
# │   │       │   │   │       ├── A1
# │   │       │   │   │       └── A2
# │   │       │   │   ├── C2
# │   │       │   │   │   ├── B270
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   ├── B271
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   └── B272
# │   │       │   │   │       ├── A1
# │   │       │   │   │       └── A2
# │   │       │   │   ├── C3
# │   │       │   │   │   ├── B273
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   ├── B274
# │   │       │   │   │   │   ├── A1
# │   │       │   │   │   │   └── A2
# │   │       │   │   │   └── B275
# │   │       │   │   │       ├── A1
# │   │       │   │   │       └── A2
# │   │       │   │   ├── C4
# │   │       │   │   │   └── B276
# │   │       │   │   │       ├── A1
# │   │       │   │   │       └── A2
# │   │       │   │   └── C5
# │   │       │   │       └── B277
# │   │       │   │           ├── A1
# │   │       │   │           └── A2
# │   │       │   └── D4
# │   │       │       ├── C1
# │   │       │       │   ├── B280
# │   │       │       │   │   ├── A1
# │   │       │       │   │   └── A2
# │   │       │       │   ├── B281
# │   │       │       │   │   ├── A1
# │   │       │       │   │   └── A2
# │   │       │       │   └── B282
# │   │       │       │       ├── A1
# │   │       │       │       └── A2
# │   │       │       ├── C2
# │   │       │       │   ├── B283
# │   │       │       │   │   ├── A1
# │   │       │       │   │   └── A2
# │   │       │       │   ├── B284
# │   │       │       │   │   ├── A1
# │   │       │       │   │   └── A2
# │   │       │       │   └── B285
# │   │       │       │       ├── A1
# │   │       │       │       └── A2
# │   │       │       ├── C3
# │   │       │       │   ├── B286
# │   │       │       │   │   ├── A1
# │   │       │       │   │   └── A2
# │   │       │       │   ├── B287
# │   │       │       │   │   ├── A1
# │   │       │       │   │   └── A2
# │   │       │       │   └── B288
# │   │       │       │       ├── A1
# │   │       │       │       └── A2
# │   │       │       ├── C4
# │   │       │       │   └── B289
# │   │       │       │       ├── A1
# │   │       │       │       └── A2
# │   │       │       └── C5
# │   │       │           └── B290
# │   │       │               ├── A1
# │   │       │               └── A2
# │   │       └── E2
# │   │           ├── D1
# │   │           │   ├── C1
# │   │           │   │   ├── B301
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   ├── B302
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   └── B303
# │   │           │   │       ├── A1
# │   │           │   │       └── A2
# │   │           │   ├── C2
# │   │           │   │   ├── B304
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   ├── B305
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   └── B306
# │   │           │   │       ├── A1
# │   │           │   │       └── A2
# │   │           │   ├── C3
# │   │           │   │   ├── B307
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   ├── B308
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   └── B309
# │   │           │   │       ├── A1
# │   │           │   │       └── A2
# │   │           │   ├── C4
# │   │           │   │   └── B310
# │   │           │   │       ├── A1
# │   │           │   │       └── A2
# │   │           │   └── C5
# │   │           │       └── B311
# │   │           │           ├── A1
# │   │           │           └── A2
# │   │           ├── D2
# │   │           │   ├── C1
# │   │           │   │   ├── B314
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   ├── B315
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   └── B316
# │   │           │   │       ├── A1
# │   │           │   │       └── A2
# │   │           │   ├── C2
# │   │           │   │   ├── B317
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   ├── B318
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   └── B319
# │   │           │   │       ├── A1
# │   │           │   │       └── A2
# │   │           │   ├── C3
# │   │           │   │   ├── B320
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   ├── B321
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   └── B322
# │   │           │   │       ├── A1
# │   │           │   │       └── A2
# │   │           │   ├── C4
# │   │           │   │   └── B323
# │   │           │   │       ├── A1
# │   │           │   │       └── A2
# │   │           │   └── C5
# │   │           │       └── B324
# │   │           │           ├── A1
# │   │           │           └── A2
# │   │           ├── D3
# │   │           │   ├── C1
# │   │           │   │   ├── B327
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   ├── B328
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   └── B329
# │   │           │   │       ├── A1
# │   │           │   │       └── A2
# │   │           │   ├── C2
# │   │           │   │   ├── B330
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   ├── B331
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   └── B332
# │   │           │   │       ├── A1
# │   │           │   │       └── A2
# │   │           │   ├── C3
# │   │           │   │   ├── B333
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   ├── B334
# │   │           │   │   │   ├── A1
# │   │           │   │   │   └── A2
# │   │           │   │   └── B335
# │   │           │   │       ├── A1
# │   │           │   │       └── A2
# │   │           │   ├── C4
# │   │           │   │   └── B336
# │   │           │   │       ├── A1
# │   │           │   │       └── A2
# │   │           │   └── C5
# │   │           │       └── B337
# │   │           │           ├── A1
# │   │           │           └── A2
# │   │           └── D4
# │   │               ├── C1
# │   │               │   ├── B340
# │   │               │   │   ├── A1
# │   │               │   │   └── A2
# │   │               │   ├── B341
# │   │               │   │   ├── A1
# │   │               │   │   └── A2
# │   │               │   └── B342
# │   │               │       ├── A1
# │   │               │       └── A2
# │   │               ├── C2
# │   │               │   ├── B343
# │   │               │   │   ├── A1
# │   │               │   │   └── A2
# │   │               │   ├── B344
# │   │               │   │   ├── A1
# │   │               │   │   └── A2
# │   │               │   └── B345
# │   │               │       ├── A1
# │   │               │       └── A2
# │   │               ├── C3
# │   │               │   ├── B346
# │   │               │   │   ├── A1
# │   │               │   │   └── A2
# │   │               │   ├── B347
# │   │               │   │   ├── A1
# │   │               │   │   └── A2
# │   │               │   └── B348
# │   │               │       ├── A1
# │   │               │       └── A2
# │   │               ├── C4
# │   │               │   └── B349
# │   │               │       ├── A1
# │   │               │       └── A2
# │   │               └── C5
# │   │                   └── B350
# │   │                       ├── A1
# │   │                       └── A2
# │   ├── G2
# │   │   ├── F1
# │   │   │   ├── E1
# │   │   │   │   ├── D1
# │   │   │   │   │   ├── C1
# │   │   │   │   │   │   ├── B361
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B362
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B363
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C2
# │   │   │   │   │   │   ├── B364
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B365
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B366
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C3
# │   │   │   │   │   │   ├── B367
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B368
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B369
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C4
# │   │   │   │   │   │   └── B370
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   └── C5
# │   │   │   │   │       └── B371
# │   │   │   │   │           ├── A1
# │   │   │   │   │           └── A2
# │   │   │   │   ├── D2
# │   │   │   │   │   ├── C1
# │   │   │   │   │   │   ├── B374
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B375
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B376
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C2
# │   │   │   │   │   │   ├── B377
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B378
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B379
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C3
# │   │   │   │   │   │   ├── B380
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B381
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B382
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C4
# │   │   │   │   │   │   └── B383
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   └── C5
# │   │   │   │   │       └── B384
# │   │   │   │   │           ├── A1
# │   │   │   │   │           └── A2
# │   │   │   │   ├── D3
# │   │   │   │   │   ├── C1
# │   │   │   │   │   │   ├── B387
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B388
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B389
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C2
# │   │   │   │   │   │   ├── B390
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B391
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B392
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C3
# │   │   │   │   │   │   ├── B393
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B394
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B395
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C4
# │   │   │   │   │   │   └── B396
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   └── C5
# │   │   │   │   │       └── B397
# │   │   │   │   │           ├── A1
# │   │   │   │   │           └── A2
# │   │   │   │   └── D4
# │   │   │   │       ├── C1
# │   │   │   │       │   ├── B400
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   ├── B401
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   └── B402
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       ├── C2
# │   │   │   │       │   ├── B403
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   ├── B404
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   └── B405
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       ├── C3
# │   │   │   │       │   ├── B406
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   ├── B407
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   └── B408
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       ├── C4
# │   │   │   │       │   └── B409
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       └── C5
# │   │   │   │           └── B410
# │   │   │   │               ├── A1
# │   │   │   │               └── A2
# │   │   │   └── E2
# │   │   │       ├── D1
# │   │   │       │   ├── C1
# │   │   │       │   │   ├── B421
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B422
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B423
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C2
# │   │   │       │   │   ├── B424
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B425
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B426
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C3
# │   │   │       │   │   ├── B427
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B428
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B429
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C4
# │   │   │       │   │   └── B430
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   └── C5
# │   │   │       │       └── B431
# │   │   │       │           ├── A1
# │   │   │       │           └── A2
# │   │   │       ├── D2
# │   │   │       │   ├── C1
# │   │   │       │   │   ├── B434
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B435
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B436
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C2
# │   │   │       │   │   ├── B437
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B438
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B439
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C3
# │   │   │       │   │   ├── B440
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B441
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B442
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C4
# │   │   │       │   │   └── B443
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   └── C5
# │   │   │       │       └── B444
# │   │   │       │           ├── A1
# │   │   │       │           └── A2
# │   │   │       ├── D3
# │   │   │       │   ├── C1
# │   │   │       │   │   ├── B447
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B448
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B449
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C2
# │   │   │       │   │   ├── B450
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B451
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B452
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C3
# │   │   │       │   │   ├── B453
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B454
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B455
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C4
# │   │   │       │   │   └── B456
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   └── C5
# │   │   │       │       └── B457
# │   │   │       │           ├── A1
# │   │   │       │           └── A2
# │   │   │       └── D4
# │   │   │           ├── C1
# │   │   │           │   ├── B460
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   ├── B461
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   └── B462
# │   │   │           │       ├── A1
# │   │   │           │       └── A2
# │   │   │           ├── C2
# │   │   │           │   ├── B463
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   ├── B464
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   └── B465
# │   │   │           │       ├── A1
# │   │   │           │       └── A2
# │   │   │           ├── C3
# │   │   │           │   ├── B466
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   ├── B467
# │   │   │           │   │   ├── A1
# │   │   │           │   │   └── A2
# │   │   │           │   └── B468
# │   │   │           │       ├── A1
# │   │   │           │       └── A2
# │   │   │           ├── C4
# │   │   │           │   └── B469
# │   │   │           │       ├── A1
# │   │   │           │       └── A2
# │   │   │           └── C5
# │   │   │               └── B470
# │   │   │                   ├── A1
# │   │   │                   └── A2
# │   │   ├── F2
# │   │   │   ├── E1
# │   │   │   │   ├── D1
# │   │   │   │   │   ├── C1
# │   │   │   │   │   │   ├── B481
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B482
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B483
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C2
# │   │   │   │   │   │   ├── B484
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B485
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B486
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C3
# │   │   │   │   │   │   ├── B487
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B488
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B489
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C4
# │   │   │   │   │   │   └── B490
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   └── C5
# │   │   │   │   │       └── B491
# │   │   │   │   │           ├── A1
# │   │   │   │   │           └── A2
# │   │   │   │   ├── D2
# │   │   │   │   │   ├── C1
# │   │   │   │   │   │   ├── B494
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B495
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B496
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C2
# │   │   │   │   │   │   ├── B497
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B498
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B499
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C3
# │   │   │   │   │   │   ├── B500
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B501
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B502
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C4
# │   │   │   │   │   │   └── B503
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   └── C5
# │   │   │   │   │       └── B504
# │   │   │   │   │           ├── A1
# │   │   │   │   │           └── A2
# │   │   │   │   ├── D3
# │   │   │   │   │   ├── C1
# │   │   │   │   │   │   ├── B507
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B508
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B509
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C2
# │   │   │   │   │   │   ├── B510
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B511
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B512
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C3
# │   │   │   │   │   │   ├── B513
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   ├── B514
# │   │   │   │   │   │   │   ├── A1
# │   │   │   │   │   │   │   └── A2
# │   │   │   │   │   │   └── B515
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   ├── C4
# │   │   │   │   │   │   └── B516
# │   │   │   │   │   │       ├── A1
# │   │   │   │   │   │       └── A2
# │   │   │   │   │   └── C5
# │   │   │   │   │       └── B517
# │   │   │   │   │           ├── A1
# │   │   │   │   │           └── A2
# │   │   │   │   └── D4
# │   │   │   │       ├── C1
# │   │   │   │       │   ├── B520
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   ├── B521
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   └── B522
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       ├── C2
# │   │   │   │       │   ├── B523
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   ├── B524
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   └── B525
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       ├── C3
# │   │   │   │       │   ├── B526
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   ├── B527
# │   │   │   │       │   │   ├── A1
# │   │   │   │       │   │   └── A2
# │   │   │   │       │   └── B528
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       ├── C4
# │   │   │   │       │   └── B529
# │   │   │   │       │       ├── A1
# │   │   │   │       │       └── A2
# │   │   │   │       └── C5
# │   │   │   │           └── B530
# │   │   │   │               ├── A1
# │   │   │   │               └── A2
# │   │   │   └── E2
# │   │   │       ├── D1
# │   │   │       │   ├── C1
# │   │   │       │   │   ├── B541
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B542
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B543
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C2
# │   │   │       │   │   ├── B544
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B545
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B546
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C3
# │   │   │       │   │   ├── B547
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   ├── B548
# │   │   │       │   │   │   ├── A1
# │   │   │       │   │   │   └── A2
# │   │   │       │   │   └── B549
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   ├── C4
# │   │   │       │   │   └── B550
# │   │   │       │   │       ├── A1
# │   │   │       │   │       └── A2
# │   │   │       │   └── C5
# │   │   │       │       └── B551
# │   │   │       │           ├── A1
# │   │   │       │           └── A2
# ...
#         │   │       │       └── A2
#         │   │       ├── C4
#         │   │       │   └── B6649
#         │   │       │       ├── A1
#         │   │       │       └── A2
#         │   │       └── C5
#         │   │           └── B6650
#         │   │               ├── A1
#         │   │               └── A2
#         │   └── E2
#         │       ├── D1
#         │       │   ├── C1
#         │       │   │   ├── B6661
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   ├── B6662
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   └── B6663
#         │       │   │       ├── A1
#         │       │   │       └── A2
#         │       │   ├── C2
#         │       │   │   ├── B6664
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   ├── B6665
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   └── B6666
#         │       │   │       ├── A1
#         │       │   │       └── A2
#         │       │   ├── C3
#         │       │   │   ├── B6667
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   ├── B6668
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   └── B6669
#         │       │   │       ├── A1
#         │       │   │       └── A2
#         │       │   ├── C4
#         │       │   │   └── B6670
#         │       │   │       ├── A1
#         │       │   │       └── A2
#         │       │   └── C5
#         │       │       └── B6671
#         │       │           ├── A1
#         │       │           └── A2
#         │       ├── D2
#         │       │   ├── C1
#         │       │   │   ├── B6674
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   ├── B6675
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   └── B6676
#         │       │   │       ├── A1
#         │       │   │       └── A2
#         │       │   ├── C2
#         │       │   │   ├── B6677
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   ├── B6678
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   └── B6679
#         │       │   │       ├── A1
#         │       │   │       └── A2
#         │       │   ├── C3
#         │       │   │   ├── B6680
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   ├── B6681
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   └── B6682
#         │       │   │       ├── A1
#         │       │   │       └── A2
#         │       │   ├── C4
#         │       │   │   └── B6683
#         │       │   │       ├── A1
#         │       │   │       └── A2
#         │       │   └── C5
#         │       │       └── B6684
#         │       │           ├── A1
#         │       │           └── A2
#         │       ├── D3
#         │       │   ├── C1
#         │       │   │   ├── B6687
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   ├── B6688
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   └── B6689
#         │       │   │       ├── A1
#         │       │   │       └── A2
#         │       │   ├── C2
#         │       │   │   ├── B6690
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   ├── B6691
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   └── B6692
#         │       │   │       ├── A1
#         │       │   │       └── A2
#         │       │   ├── C3
#         │       │   │   ├── B6693
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   ├── B6694
#         │       │   │   │   ├── A1
#         │       │   │   │   └── A2
#         │       │   │   └── B6695
#         │       │   │       ├── A1
#         │       │   │       └── A2
#         │       │   ├── C4
#         │       │   │   └── B6696
#         │       │   │       ├── A1
#         │       │   │       └── A2
#         │       │   └── C5
#         │       │       └── B6697
#         │       │           ├── A1
#         │       │           └── A2
#         │       └── D4
#         │           ├── C1
#         │           │   ├── B6700
#         │           │   │   ├── A1
#         │           │   │   └── A2
#         │           │   ├── B6701
#         │           │   │   ├── A1
#         │           │   │   └── A2
#         │           │   └── B6702
#         │           │       ├── A1
#         │           │       └── A2
#         │           ├── C2
#         │           │   ├── B6703
#         │           │   │   ├── A1
#         │           │   │   └── A2
#         │           │   ├── B6704
#         │           │   │   ├── A1
#         │           │   │   └── A2
#         │           │   └── B6705
#         │           │       ├── A1
#         │           │       └── A2
#         │           ├── C3
#         │           │   ├── B6706
#         │           │   │   ├── A1
#         │           │   │   └── A2
#         │           │   ├── B6707
#         │           │   │   ├── A1
#         │           │   │   └── A2
#         │           │   └── B6708
#         │           │       ├── A1
#         │           │       └── A2
#         │           ├── C4
#         │           │   └── B6709
#         │           │       ├── A1
#         │           │       └── A2
#         │           └── C5
#         │               └── B6710
#         │                   ├── A1
#         │                   └── A2
#         └── F3
#             ├── E1
#             │   ├── D1
#             │   │   ├── C1
#             │   │   │   ├── B6721
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   ├── B6722
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   └── B6723
#             │   │   │       ├── A1
#             │   │   │       └── A2
#             │   │   ├── C2
#             │   │   │   ├── B6724
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   ├── B6725
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   └── B6726
#             │   │   │       ├── A1
#             │   │   │       └── A2
#             │   │   ├── C3
#             │   │   │   ├── B6727
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   ├── B6728
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   └── B6729
#             │   │   │       ├── A1
#             │   │   │       └── A2
#             │   │   ├── C4
#             │   │   │   └── B6730
#             │   │   │       ├── A1
#             │   │   │       └── A2
#             │   │   └── C5
#             │   │       └── B6731
#             │   │           ├── A1
#             │   │           └── A2
#             │   ├── D2
#             │   │   ├── C1
#             │   │   │   ├── B6734
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   ├── B6735
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   └── B6736
#             │   │   │       ├── A1
#             │   │   │       └── A2
#             │   │   ├── C2
#             │   │   │   ├── B6737
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   ├── B6738
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   └── B6739
#             │   │   │       ├── A1
#             │   │   │       └── A2
#             │   │   ├── C3
#             │   │   │   ├── B6740
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   ├── B6741
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   └── B6742
#             │   │   │       ├── A1
#             │   │   │       └── A2
#             │   │   ├── C4
#             │   │   │   └── B6743
#             │   │   │       ├── A1
#             │   │   │       └── A2
#             │   │   └── C5
#             │   │       └── B6744
#             │   │           ├── A1
#             │   │           └── A2
#             │   ├── D3
#             │   │   ├── C1
#             │   │   │   ├── B6747
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   ├── B6748
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   └── B6749
#             │   │   │       ├── A1
#             │   │   │       └── A2
#             │   │   ├── C2
#             │   │   │   ├── B6750
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   ├── B6751
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   └── B6752
#             │   │   │       ├── A1
#             │   │   │       └── A2
#             │   │   ├── C3
#             │   │   │   ├── B6753
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   ├── B6754
#             │   │   │   │   ├── A1
#             │   │   │   │   └── A2
#             │   │   │   └── B6755
#             │   │   │       ├── A1
#             │   │   │       └── A2
#             │   │   ├── C4
#             │   │   │   └── B6756
#             │   │   │       ├── A1
#             │   │   │       └── A2
#             │   │   └── C5
#             │   │       └── B6757
#             │   │           ├── A1
#             │   │           └── A2
#             │   └── D4
#             │       ├── C1
#             │       │   ├── B6760
#             │       │   │   ├── A1
#             │       │   │   └── A2
#             │       │   ├── B6761
#             │       │   │   ├── A1
#             │       │   │   └── A2
#             │       │   └── B6762
#             │       │       ├── A1
#             │       │       └── A2
#             │       ├── C2
#             │       │   ├── B6763
#             │       │   │   ├── A1
#             │       │   │   └── A2
#             │       │   ├── B6764
#             │       │   │   ├── A1
#             │       │   │   └── A2
#             │       │   └── B6765
#             │       │       ├── A1
#             │       │       └── A2
#             │       ├── C3
#             │       │   ├── B6766
#             │       │   │   ├── A1
#             │       │   │   └── A2
#             │       │   ├── B6767
#             │       │   │   ├── A1
#             │       │   │   └── A2
#             │       │   └── B6768
#             │       │       ├── A1
#             │       │       └── A2
#             │       ├── C4
#             │       │   └── B6769
#             │       │       ├── A1
#             │       │       └── A2
#             │       └── C5
#             │           └── B6770
#             │               ├── A1
#             │               └── A2
#             └── E2
#                 ├── D1
#                 │   ├── C1
#                 │   │   ├── B6781
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   ├── B6782
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   └── B6783
#                 │   │       ├── A1
#                 │   │       └── A2
#                 │   ├── C2
#                 │   │   ├── B6784
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   ├── B6785
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   └── B6786
#                 │   │       ├── A1
#                 │   │       └── A2
#                 │   ├── C3
#                 │   │   ├── B6787
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   ├── B6788
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   └── B6789
#                 │   │       ├── A1
#                 │   │       └── A2
#                 │   ├── C4
#                 │   │   └── B6790
#                 │   │       ├── A1
#                 │   │       └── A2
#                 │   └── C5
#                 │       └── B6791
#                 │           ├── A1
#                 │           └── A2
#                 ├── D2
#                 │   ├── C1
#                 │   │   ├── B6794
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   ├── B6795
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   └── B6796
#                 │   │       ├── A1
#                 │   │       └── A2
#                 │   ├── C2
#                 │   │   ├── B6797
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   ├── B6798
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   └── B6799
#                 │   │       ├── A1
#                 │   │       └── A2
#                 │   ├── C3
#                 │   │   ├── B6800
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   ├── B6801
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   └── B6802
#                 │   │       ├── A1
#                 │   │       └── A2
#                 │   ├── C4
#                 │   │   └── B6803
#                 │   │       ├── A1
#                 │   │       └── A2
#                 │   └── C5
#                 │       └── B6804
#                 │           ├── A1
#                 │           └── A2
#                 ├── D3
#                 │   ├── C1
#                 │   │   ├── B6807
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   ├── B6808
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   └── B6809
#                 │   │       ├── A1
#                 │   │       └── A2
#                 │   ├── C2
#                 │   │   ├── B6810
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   ├── B6811
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   └── B6812
#                 │   │       ├── A1
#                 │   │       └── A2
#                 │   ├── C3
#                 │   │   ├── B6813
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   ├── B6814
#                 │   │   │   ├── A1
#                 │   │   │   └── A2
#                 │   │   └── B6815
#                 │   │       ├── A1
#                 │   │       └── A2
#                 │   ├── C4
#                 │   │   └── B6816
#                 │   │       ├── A1
#                 │   │       └── A2
#                 │   └── C5
#                 │       └── B6817
#                 │           ├── A1
#                 │           └── A2
#                 └── D4
#                     ├── C1
#                     │   ├── B6820
#                     │   │   ├── A1
#                     │   │   └── A2
#                     │   ├── B6821
#                     │   │   ├── A1
#                     │   │   └── A2
#                     │   └── B6822
#                     │       ├── A1
#                     │       └── A2
#                     ├── C2
#                     │   ├── B6823
#                     │   │   ├── A1
#                     │   │   └── A2
#                     │   ├── B6824
#                     │   │   ├── A1
#                     │   │   └── A2
#                     │   └── B6825
#                     │       ├── A1
#                     │       └── A2
#                     ├── C3
#                     │   ├── B6826
#                     │   │   ├── A1
#                     │   │   └── A2
#                     │   ├── B6827
#                     │   │   ├── A1
#                     │   │   └── A2
#                     │   └── B6828
#                     │       ├── A1
#                     │       └── A2
#                     ├── C4
#                     │   └── B6829
#                     │       ├── A1
#                     │       └── A2
#                     └── C5
#                         └── B6830
#                             ├── A1
#                             └── A2
#
# None

# %%
first_level=8
for i in range(1,first_level+1):
    update_input(i,first_level)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(my_dict)

# %%
os.remove("tree2.csv")

# %%
try:
    print("test1")
    try:
        os.remove("tree.csv")
    except FileNotFoundError:
        pass
    print("test2")
except Exception as e:
    print(e)
# Out:
# test1
# test2
